# %% [markdown]
# ## Mixing a spatial constraint and a properties constraint
#
# We now want to bind a spatial and a properties constraints to the Constraints object so that our mocserver query returns all the datasets matching those two constraints.

# %%
from astropy import coordinates
from regions import CircleSkyRegion

# mocserver object derived from astroquery.query.BaseQuery
from mocserver.core import mocserver

from mocserver.constraints import Constraints
from mocserver.spatial_constraints import Moc
from mocserver.property_constraint import *
from mocserver.output_format import OutputFormat

# %% [markdown]
# As for the spatial constraint, let is define a moc from an url

# %%
moc = Moc.from_url(url='http://alasky.u-strasbg.fr/SDSS/DR9/color/Moc.fits', intersect='overlaps')

# %% [markdown]
# Let is define a properties constraint. Here we want to retrieve all datasets satisfying the following expression :
# (ID = \*CDS\* && moc_sky_fraction <= 0.01)
#
# In other words, we want to retrieve all datasets coming from the CDS and having a moc_sky_fraction of at least 1%.
#
# A properties constraint is written like an algebraic tree of equalities/inequalities. For instance, the above algebraic expression will be defined such as :

# %%
properties_constraint = PropertyConstraint(ParentNode(
    OperandExpr.Inter,
    ChildNode("moc_sky_fraction <= 0.01"),
    ChildNode("ID = *CDS*")
))

# %% [markdown]
# Once we defined our two constraints (i.e. a spatial one and a properties one), we can bind them to a Constraints object

# %%
mocserver_constraints = Constraints(sc=moc, pc=properties_constraint)

# %% [markdown]
# And simply call the mocserver object to run the query

# %%
response = mocserver.query_region(mocserver_constraints,
                                  OutputFormat(format=OutputFormat.Type.id))
response
# Out:
# Final Request payload before requesting to alasky
# {'casesensitive': 'true',
#  'expr': 'moc_sky_fraction <= 0.01 && ID = *CDS*',
#  'fmt': 'json',
#  'get': 'id',
#  'intersect': 'overlaps',
#  'url': 'http://alasky.u-strasbg.fr/SDSS/DR9/color/Moc.fits'}
# <Response [200]>
# ['CDS/B/avo.rad/catalog',
#  'CDS/B/avo.rad/wsrt',
#  'CDS/B/bax/bax',
#  'CDS/B/cb/cbdata',
#  'CDS/B/cb/lmxbdata',
#  'CDS/B/cb/pcbdata',
#  'CDS/B/cfht/cfht',
#  'CDS/B/cfht/obscore',
#  'CDS/B/chandra/chandra',
#  'CDS/B/corot/Bright_star',
#  'CDS/B/corot/Faint_star',
#  'CDS/B/eso/eso_arc',
#  'CDS/B/gcvs/evs_cat',
#  'CDS/B/gcvs/gcvs_cat',
#  'CDS/B/gcvs/nsv_cat',
#  'CDS/B/gemini/obscore',
#  'CDS/B/hst/hstlog',
#  'CDS/B/hst/obscore',
#  'CDS/B/hst/wfpc2',
#  'CDS/B/int/obs',
#  'CDS/B/iram/30m',
#  'CDS/B/iram/noema',
#  'CDS/B/iram/pdbi',
#  'CDS/B/jcmt/obscore',
#  'CDS/B/merlin/merlin',
#  'CDS/B/occ/moon',
#  'CDS/B/ocl/clusters',
#  'CDS/B/ocl/removed',
#  'CDS/B/pastel/pastel',
#  'CDS/B/psr/psr',
#  'CDS/B/sb9/main',
#  'CDS/B/sn/sncat',
#  'CDS/B/subaru/suprimc',
#  'CDS/B/swift/swiftlog',
#  'CDS/B/vsx/vsx',
#  'CDS/B/wd/catalog',
#  'CDS/B/wds/wds',
#  'CDS/B/xmm/xmmlog',
#  'CDS/C/CALIFA/V500/DR2',
#  'CDS/C/MUSE-M42',
#  'CDS/I/100A/w10',
#  'CDS/I/100A/w25',
#  'CDS/I/100A/w50',
#  'CDS/I/108/cpd',
#  'CDS/I/112A/pos158',
#  'CDS/I/112A/south',
#  'CDS/I/113A/catalog',
#  'CDS/I/119/sd',
#  'CDS/I/121/cpm',
#  'CDS/I/122/bd',
#  'CDS/I/125A/catalog',
#  'CDS/I/128/data',
#  'CDS/I/130/main',
#  'CDS/I/130/rejected',
#  'CDS/I/131A/sao',
#  'CDS/I/138/main',
#  'CDS/I/141/yale00',
#  'CDS/I/143/fk4_1950',
#  'CDS/I/143/fk4_1955',
#  'CDS/I/143/fk4_1960',
#  'CDS/I/143/fk4_1965',
#  'CDS/I/143/fk4_1970',
#  'CDS/I/143/fk4_1975',
#  'CDS/I/143/fk4_supp',
#  'CDS/I/144/hxcat',
#  'CDS/I/146/ppm1',
#  'CDS/I/147/table1',
#  'CDS/I/147/table5',
#  'CDS/I/149A/catalog',
#  'CDS/I/150/catalog',
#  'CDS/I/151/table3',
#  'CDS/I/151/table4',
#  'CDS/I/152/catalog',
#  'CDS/I/153/catalog',
#  'CDS/I/157/zzcat',
#  'CDS/I/16/catalog',
#  'CDS/I/161/agk3r',
#  'CDS/I/167/pmc86',
#  'CDS/I/170A/table1',
#  'CDS/I/170A/table5',
#  'CDS/I/171/acrs1',
#  'CDS/I/172/irs',
#  'CDS/I/175/fk5e',
#  'CDS/I/176/catalog',
#  'CDS/I/180/gcpa',
#  'CDS/I/182/pacp4',
#  'CDS/I/186/pmc85',
#  'CDS/I/187/pmc87',
#  'CDS/I/188/pmc88',
#  'CDS/I/189/table1',
#  'CDS/I/189/table5',
#  'CDS/I/193/ppm2',
#  'CDS/I/195/catalog',
#  'CDS/I/196/annex1',
#  'CDS/I/196/main',
#  'CDS/I/198/catalog',
#  'CDS/I/199A/npm1j',
#  'CDS/I/200/npm1rgal',
#  'CDS/I/201/b1950',
#  'CDS/I/202/fk5e1950',
#  'CDS/I/202/fk5emean',
#  'CDS/I/203/catalog',
#  'CDS/I/205/table1',
#  'CDS/I/205/table5',
#  'CDS/I/206/ppmb',
#  'CDS/I/208/ppm3',
#  'CDS/I/209A/main',
#  'CDS/I/210/catalog',
#  'CDS/I/211/catalog',
#  'CDS/I/213/table1',
#  'CDS/I/213/table5',
#  'CDS/I/218/refframe',
#  'CDS/I/222/sanfac',
#  'CDS/I/223/algac',
#  'CDS/I/224/oxf1ac',
#  'CDS/I/225/oxf2ac',
#  'CDS/I/226/vatac',
#  'CDS/I/227/parac',
#  'CDS/I/228/bordac',
#  'CDS/I/230/shb',
#  'CDS/I/231/uccac',
#  'CDS/I/232/toulac',
#  'CDS/I/237/catalog',
#  'CDS/I/237/notes',
#  'CDS/I/237/notesyns',
#  'CDS/I/238A/picat',
#  'CDS/I/239/h_dm_com',
#  'CDS/I/239/hip_main',
#  'CDS/I/239/solar_ha',
#  'CDS/I/239/solar_t',
#  'CDS/I/241/n70e',
#  'CDS/I/242/pvc96',
#  'CDS/I/248/catalog',
#  'CDS/I/249/catalog',
#  'CDS/I/251/rsc95r01',
#  'CDS/I/251/rsc95r02',
#  'CDS/I/256/fk5l',
#  'CDS/I/256/fk5u',
#  'CDS/I/256/nltt',
#  'CDS/I/256/novapos',
#  'CDS/I/256/stars',
#  'CDS/I/256/varpos',
#  'CDS/I/256/veronc81',
#  'CDS/I/256/veronc82',
#  'CDS/I/256/veronc83',
#  'CDS/I/257B/catalog',
#  'CDS/I/259/suppl_1',
#  'CDS/I/259/suppl_2',
#  'CDS/I/260/ccdmhipn',
#  'CDS/I/263/acr_a',
#  'CDS/I/263/table1',
#  'CDS/I/264/fk6_1',
#  'CDS/I/264/fk6_3',
#  'CDS/I/265/cpc2app',
#  'CDS/I/265/cpc2main',
#  'CDS/I/270/cpirss01',
#  'CDS/I/273A/erlcat',
#  'CDS/I/274/ccdm',
#  'CDS/I/276/catalog',
#  'CDS/I/276/supplem',
#  'CDS/I/277/spmcat',
#  'CDS/I/278/catalog',
#  'CDS/I/279/catalog',
#  'CDS/I/282/cmc12rej',
#  'CDS/I/283A/npm2',
#  'CDS/I/285/gpm',
#  'CDS/I/285/region',
#  'CDS/I/290/centers',
#  'CDS/I/290/pul3',
#  'CDS/I/291/xz80q',
#  'CDS/I/292/table',
#  'CDS/I/293/npm2cros',
#  'CDS/I/294A/ucac2bss',
#  'CDS/I/295/catalog',
#  'CDS/I/298/lspm_n',
#  'CDS/I/298/table3',
#  'CDS/I/302/xcfields',
#  'CDS/I/303/cdc2000',
#  'CDS/I/308/catalog',
#  'CDS/I/309/bs-726',
#  'CDS/I/309/srs-5969',
#  'CDS/I/31/ksz',
#  'CDS/I/310/agk1',
#  'CDS/I/311/hip2',
#  'CDS/I/313/lqrf',
#  'CDS/I/316/gr',
#  'CDS/I/321/lspm',
#  'CDS/I/321/smp',
#  'CDS/I/323/icrf2',
#  'CDS/I/325/icrf-u2',
#  'CDS/I/325/icrf-u4',
#  'CDS/I/326/pgrsdat',
#  'CDS/I/326/spgrsdat',
#  'CDS/I/328/table1',
#  'CDS/I/332/kmac2',
#  'CDS/I/333/upc',
#  'CDS/I/334/w1j00sta',
#  'CDS/I/334/w2j00sta',
#  'CDS/I/335/table1',
#  'CDS/I/337/qso',
#  'CDS/I/34/greenw2a',
#  'CDS/I/34/greenw2b',
#  'CDS/I/344/upcn',
#  'CDS/I/344/upcs',
#  'CDS/I/40/catalog',
#  'CDS/I/42/catalog',
#  'CDS/I/44/spf2',
#  'CDS/I/45/catalog',
#  'CDS/I/54A/catalog',
#  'CDS/I/57/catalog',
#  'CDS/I/61B/agk3',
#  'CDS/I/62C/catalog',
#  'CDS/I/65/catalog',
#  'CDS/I/68A/main',
#  'CDS/I/71/catalog',
#  'CDS/I/72/catalog',
#  'CDS/I/78/catalog',
#  'CDS/I/79/north',
#  'CDS/I/80/n30',
#  'CDS/I/82/catalog',
#  'CDS/I/87B/catalog',
#  'CDS/I/97/perth75',
#  'CDS/I/98A/catalog',
#  'CDS/I/98A/remarks',
#  'CDS/I/99/phtelec',
#  'CDS/I/99/phtgrpc',
#  'CDS/II/106/catalog',
#  'CDS/II/114/catalog',
#  'CDS/II/115A/catalog',
#  'CDS/II/118/main',
#  'CDS/II/121/sa127',
#  'CDS/II/122B/merged',
#  'CDS/II/125/main',
#  'CDS/II/126/sources',
#  'CDS/II/134/data',
#  'CDS/II/135/catalog',
#  'CDS/II/139B/catalog',
#  'CDS/II/143A/catalog',
#  'CDS/II/144/catalog',
#  'CDS/II/145/catalog',
#  'CDS/II/149/catalog',
#  'CDS/II/15/mean',
#  'CDS/II/156A/main',
#  'CDS/II/157A/catalog',
#  'CDS/II/159/catalog',
#  'CDS/II/161/catalog',
#  'CDS/II/164/mean',
#  'CDS/II/167/catalog',
#  'CDS/II/168/ubvmeans',
#  'CDS/II/169/main',
#  'CDS/II/170/stars1',
#  'CDS/II/171/catalog',
#  'CDS/II/175/stars',
#  'CDS/II/178/catalog',
#  'CDS/II/179/stars',
#  'CDS/II/18/mean',
#  'CDS/II/180/table1',
#  'CDS/II/182/ubv',
#  'CDS/II/183A/table2',
#  'CDS/II/188/stars2',
#  'CDS/II/190/fp108a',
#  'CDS/II/192/catalog',
#  'CDS/II/195B/nl',
#  'CDS/II/195B/nl73',
#  'CDS/II/196/table2',
#  'CDS/II/196/table3',
#  'CDS/II/196/table4',
#  'CDS/II/197/table1',
#  'CDS/II/199A/stars',
#  'CDS/II/200/stars3',
#  'CDS/II/201/catalog',
#  'CDS/II/202/stars4',
#  'CDS/II/203A/faint',
#  'CDS/II/203A/table1',
#  'CDS/II/203A/table2',
#  'CDS/II/203A/table3',
#  'CDS/II/205/evs_cat',
#  'CDS/II/205/sn_cat',
#  'CDS/II/206/bcsp',
#  'CDS/II/207A/catalog',
#  'CDS/II/208/bv',
#  'CDS/II/211/catalog',
#  'CDS/II/211/ircam',
#  'CDS/II/211/spectro',
#  'CDS/II/212A/uv',
#  'CDS/II/214A/evs_cat',
#  'CDS/II/214A/gcvs',
#  'CDS/II/214A/nsv',
#  'CDS/II/214A/sn_cat',
#  'CDS/II/215/catalog',
#  'CDS/II/217/stars',
#  'CDS/II/218/sn',
#  'CDS/II/219/nsv',
#  'CDS/II/219/nsvs',
#  'CDS/II/21A/catalog',
#  'CDS/II/22/catalog',
#  'CDS/II/220/stars',
#  'CDS/II/221A/lf',
#  'CDS/II/223/fbs2',
#  'CDS/II/224/cadars',
#  'CDS/II/225/catalog',
#  'CDS/II/225/names',
#  'CDS/II/225/psc',
#  'CDS/II/226/catalog',
#  'CDS/II/227/sncat',
#  'CDS/II/230/catalog',
#  'CDS/II/231/lanning',
#  'CDS/II/233/tableb-v',
#  'CDS/II/233/tablet',
#  'CDS/II/235/deltam',
#  'CDS/II/237/colors',
#  'CDS/II/238/b-r99-01',
#  'CDS/II/238/b-v97-98',
#  'CDS/II/238/tab82-96',
#  'CDS/II/238/tab97-01',
#  'CDS/II/239/catalog',
#  'CDS/II/24/data',
#  'CDS/II/243/denis',
#  'CDS/II/243/fields',
#  'CDS/II/243/ghosts1',
#  'CDS/II/243/ghosts2',
#  'CDS/II/243/ghosts3',
#  'CDS/II/243/isoobs',
#  'CDS/II/243/psc1',
#  'CDS/II/243/psc2',
#  'CDS/II/248/catalog',
#  'CDS/II/249/catalog',
#  'CDS/II/25/catalog',
#  'CDS/II/250/evs_cat',
#  'CDS/II/250/gcvs_cat',
#  'CDS/II/250/nsv_cat',
#  'CDS/II/250/sn_cat',
#  'CDS/II/255/iraccat',
#  'CDS/II/255/mips160',
#  'CDS/II/255/mips70',
#  'CDS/II/256/sn',
#  'CDS/II/257A/lanning',
#  'CDS/II/260/catalog',
#  'CDS/II/261/GOODS_N',
#  'CDS/II/262/batc',
#  'CDS/II/262/summary',
#  'CDS/II/264/asas-i',
#  'CDS/II/264/asas3',
#  'CDS/II/264/ivar',
#  'CDS/II/264/var',
#  'CDS/II/266/catalog',
#  'CDS/II/269/catal',
#  'CDS/II/26A/catalog',
#  'CDS/II/27/means',
#  'CDS/II/270/catal',
#  'CDS/II/270/files',
#  'CDS/II/272/gspc24',
#  'CDS/II/273/table',
#  'CDS/II/274/iras_r',
#  'CDS/II/275/assoc',
#  'CDS/II/277/loneos',
#  'CDS/II/283/sncat',
#  'CDS/II/284/cosmos',
#  'CDS/II/285/stars',
#  'CDS/II/286/bcat',
#  'CDS/II/286/icat',
#  'CDS/II/286/jcat',
#  'CDS/II/286/kcat',
#  'CDS/II/286/morph',
#  'CDS/II/286/rcat',
#  'CDS/II/286/ucat',
#  'CDS/II/286/vcat',
#  'CDS/II/290/finalcat',
#  'CDS/II/292/objects',
#  'CDS/II/292/table2',
#  'CDS/II/292/table5',
#  'CDS/II/296/catalog',
#  'CDS/II/298/fis',
#  'CDS/II/299/gd',
#  'CDS/II/2B/catalog',
#  'CDS/II/300/jsdc',
#  'CDS/II/301/catalog',
#  'CDS/II/303/ubvri',
#  'CDS/II/309/catalog',
#  'CDS/II/314/dxs8',
#  'CDS/II/317/cfhtls_d',
#  'CDS/II/317/cfhtls_w',
#  'CDS/II/318/GOODS_N',
#  'CDS/II/319/dxs9',
#  'CDS/II/326/zcatrev',
#  'CDS/II/327/ysoc',
#  'CDS/II/329/viking1',
#  'CDS/II/332/c2d',
#  'CDS/II/338/catalog',
#  'CDS/II/340/summary',
#  'CDS/II/340/xmmom2_1',
#  'CDS/II/342/hsc1',
#  'CDS/II/342/hsc2',
#  'CDS/II/345/jmdc',
#  'CDS/II/346/jsdc_dis',
#  'CDS/II/346/jsdc_v2',
#  'CDS/II/34A/catalog',
#  'CDS/II/354/hipext',
#  'CDS/II/36/ubv',
#  'CDS/II/36/uvbybeta',
#  'CDS/II/37/clusters',
#  'CDS/II/38/ph07',
#  'CDS/II/38/ph10',
#  'CDS/II/38/ph18',
#  'CDS/II/38/ph20',
#  'CDS/II/38/ph22',
#  'CDS/II/38/ph24',
#  'CDS/II/38/ph25',
#  'CDS/II/38/ph27',
#  'CDS/II/38/ph28',
#  'CDS/II/38/ph29',
#  'CDS/II/38/ph31',
#  'CDS/II/38/ph33',
#  'CDS/II/38/ph34',
#  'CDS/II/40/data',
#  'CDS/II/41/photom',
#  'CDS/II/42/data',
#  'CDS/II/43/data',
#  'CDS/II/44/data',
#  'CDS/II/45/data',
#  'CDS/II/46/table1',
#  'CDS/II/46/table4',
#  'CDS/II/47/stars',
#  'CDS/II/50/ubv',
#  'CDS/II/53/catalog',
#  'CDS/II/55/catalog',
#  'CDS/II/56/catalog',
#  'CDS/II/59B/catalog',
#  'CDS/II/5A/data',
#  'CDS/II/5A/table10',
#  'CDS/II/6/catalog',
#  'CDS/II/62/catalog',
#  'CDS/II/63A/phot42',
#  'CDS/II/63A/phot43',
#  'CDS/II/63A/phot44',
#  'CDS/II/63A/phot55',
#  'CDS/II/63A/phot56',
#  'CDS/II/63A/phot57',
#  'CDS/II/63A/phot58',
#  'CDS/II/63A/phot59',
#  'CDS/II/63A/phot60',
#  'CDS/II/63A/phot61',
#  'CDS/II/63A/phot62',
#  'CDS/II/68/catalog',
#  'CDS/II/7A/catalog',
#  'CDS/II/8/mean',
#  'CDS/II/80/catalog',
#  'CDS/II/82/catalog',
#  'CDS/II/84/catalog',
#  'CDS/II/86/suppl',
#  'CDS/II/94/main',
#  'CDS/II/94/supp',
#  'CDS/II/95/data',
#  'CDS/II/97/ans',
#  'CDS/III/105/meanvel',
#  'CDS/III/106/catalog',
#  'CDS/III/10B/catalog',
#  'CDS/III/112/catalog',
#  'CDS/III/114/stars',
#  'CDS/III/115/stars',
#  'CDS/III/116/table1',
#  'CDS/III/119/addstars',
#  'CDS/III/119/lttstars',
#  'CDS/III/120/catalog',
#  'CDS/III/121/catalog',
#  'CDS/III/123B/catalog',
#  'CDS/III/123B/stkm1',
#  'CDS/III/124/stars',
#  'CDS/III/125/data',
#  'CDS/III/126/part1',
#  'CDS/III/126/part2',
#  'CDS/III/126/part3',
#  'CDS/III/126/stars',
#  'CDS/III/127/results',
#  'CDS/III/129/main',
#  'CDS/III/13/catalog',
#  'CDS/III/130/atlas',
#  'CDS/III/131/stars',
#  'CDS/III/132/catalog',
#  'CDS/III/133/vol4',
#  'CDS/III/134/obs',
#  'CDS/III/135A/catalog',
#  'CDS/III/136/summary',
#  'CDS/III/137/catalog',
#  'CDS/III/14/ss59',
#  'CDS/III/140/data',
#  'CDS/III/143/table1',
#  'CDS/III/144/catalog',
#  'CDS/III/145/u',
#  'CDS/III/148A/apx2',
#  'CDS/III/148A/table1',
#  'CDS/III/148A/table3',
#  'CDS/III/149/catalog',
#  'CDS/III/150A/mkcat',
#  'CDS/III/153/spectra',
#  'CDS/III/156/carbon',
#  'CDS/III/156/table2',
#  'CDS/III/157/objects',
#  'CDS/III/159A/catalog',
#  'CDS/III/161/main',
#  'CDS/III/162A/catalog',
#  'CDS/III/164/catalog',
#  'CDS/III/166/stars',
#  'CDS/III/168/catalog',
#  'CDS/III/170B/mac_iras',
#  'CDS/III/170B/ps_class',
#  'CDS/III/172/table3',
#  'CDS/III/174/stars',
#  'CDS/III/175/table1',
#  'CDS/III/176/table1',
#  'CDS/III/177/catalog',
#  'CDS/III/179/stars',
#  'CDS/III/17B/catalog',
#  'CDS/III/180/catalog',
#  'CDS/III/181/stars',
#  'CDS/III/182/catalog',
#  'CDS/III/184/catalog',
#  'CDS/III/185/stars',
#  'CDS/III/188/stars',
#  'CDS/III/18B/mkclass',
#  'CDS/III/190B/web',
#  'CDS/III/191/mean',
#  'CDS/III/192/vr',
#  'CDS/III/193/catalog',
#  'CDS/III/195/objects',
#  'CDS/III/196/stars',
#  'CDS/III/197/lrs',
#  'CDS/III/198/binary',
#  'CDS/III/198/early',
#  'CDS/III/198/main',
#  'CDS/III/199A/stars',
#  'CDS/III/2/data',
#  'CDS/III/200B/clstars',
#  'CDS/III/200B/fistars',
#  'CDS/III/201/stars',
#  'CDS/III/202/catalog',
#  'CDS/III/203/table',
#  'CDS/III/204/catalog',
#  'CDS/III/205/catalog',
#  'CDS/III/206/ic1805',
#  'CDS/III/206/mk13',
#  'CDS/III/206/ngc1977',
#  'CDS/III/206/orion',
#  'CDS/III/206/scooph',
#  'CDS/III/207/catalog',
#  'CDS/III/208/catalog',
#  'CDS/III/209/stars',
#  'CDS/III/21/gcrv',
#  'CDS/III/210/catalog',
#  'CDS/III/213/catalog',
#  'CDS/III/214/vol5',
#  'CDS/III/215/table13',
#  'CDS/III/216/cat91-98',
#  'CDS/III/217/stars',
#  'CDS/III/218/table1',
#  'CDS/III/219/cluster',
#  'CDS/III/219/galaxy',
#  'CDS/III/219/star',
#  'CDS/III/22/data',
#  'CDS/III/221A/table1',
#  'CDS/III/221A/table2',
#  'CDS/III/221A/table2a',
#  'CDS/III/222/mk14',
#  'CDS/III/223/mk12',
#  'CDS/III/226/catalog',
#  'CDS/III/227/catalog',
#  'CDS/III/229/stars',
#  'CDS/III/230/catalog',
#  'CDS/III/231/catalog',
#  'CDS/III/232/table',
#  'CDS/III/235B/catalog',
#  'CDS/III/237A/catalog',
#  'CDS/III/239/catalog',
#  'CDS/III/239/rv_std',
#  'CDS/III/23B/catalog',
#  'CDS/III/242/iasd',
#  'CDS/III/243/objects',
#  'CDS/III/244/catalog',
#  'CDS/III/244/mean',
#  'CDS/III/244/standard',
#  'CDS/III/245/stars',
#  'CDS/III/246/catalog',
#  'CDS/III/246/ids1-5',
#  'CDS/III/249/catalog',
#  'CDS/III/250/vvds_dp',
#  'CDS/III/251/table1',
#  'CDS/III/252/table1',
#  'CDS/III/252/table4',
#  'CDS/III/252/table8',
#  'CDS/III/254/crvad2',
#  'CDS/III/256/ves',
#  'CDS/III/257/ravedr2',
#  'CDS/III/258/fbs',
#  'CDS/III/25A/stars',
#  'CDS/III/260/catalog',
#  'CDS/III/264/catalog',
#  'CDS/III/265/ravedr3',
#  'CDS/III/266/catalog',
#  'CDS/III/267/stars',
#  'CDS/III/268/deep2all',
#  'CDS/III/270/catalog',
#  'CDS/III/271/catalog',
#  'CDS/III/272/ravedr4',
#  'CDS/III/273/table12',
#  'CDS/III/274/main',
#  'CDS/III/275/catalog',
#  'CDS/III/276/catalog',
#  'CDS/III/277/wray_15',
#  'CDS/III/278/table1v1',
#  'CDS/III/278/table1v2',
#  'CDS/III/278/tabwb',
#  'CDS/III/279/rave_dr5',
#  'CDS/III/279/rave_on',
#  'CDS/III/27A/table5',
#  'CDS/III/280/logb',
#  'CDS/III/280/logc',
#  'CDS/III/280/logg',
#  'CDS/III/280/logh',
#  'CDS/III/280/logn',
#  'CDS/III/280/logs',
#  'CDS/III/29/catalog',
#  'CDS/III/30A/catalog',
#  'CDS/III/334/videodr2',
#  'CDS/III/39A/catalog',
#  'CDS/III/4/catalog',
#  'CDS/III/42/catalog',
#  'CDS/III/43/main',
#  'CDS/III/44/stars',
#  'CDS/III/45/spectra',
#  'CDS/III/47B/catalog',
#  'CDS/III/48B/catalog',
#  'CDS/III/49/catalog',
#  'CDS/III/53/catalog',
#  'CDS/III/55/catalog',
#  'CDS/III/58/catalog',
#  'CDS/III/59/data',
#  'CDS/III/60/catalog',
#  'CDS/III/67A/catalog',
#  'CDS/III/68/catalog',
#  'CDS/III/70/catalog',
#  'CDS/III/74/phl',
#  'CDS/III/75B/main',
#  'CDS/III/76A/ls',
#  'CDS/III/77/stars',
#  'CDS/III/78/mkext',
#  'CDS/III/83/sources',
#  'CDS/III/84B/catalog',
#  'CDS/III/85/table8',
#  'CDS/III/85/table9',
#  'CDS/III/86/frames',
#  'CDS/III/86/stars',
#  'CDS/III/88/atlas',
#  'CDS/III/89/stars',
#  'CDS/III/92/stars',
#  'CDS/III/97A/catalog',
#  'CDS/III/9A/catalog',
#  'CDS/IV/12/index',
#  'CDS/IV/20/data',
#  'CDS/IV/22/index',
#  'CDS/IV/23/var',
#  'CDS/IV/24/table1',
#  'CDS/IV/24/table2',
#  'CDS/IV/24/table3',
#  'CDS/IV/24/table4',
#  'CDS/IV/24/table5',
#  'CDS/IV/24/table6',
#  'CDS/IV/24/table8',
#  'CDS/IV/25/tyc2_hd',
#  'CDS/IV/26/catalog',
#  'CDS/IV/27A/catalog',
#  'CDS/IV/28A/stars',
#  'CDS/IV/29/tables',
#  'CDS/IV/30/stars',
#  'CDS/IX/1/Xcat',
#  'CDS/IX/10A/1rxs',
#  'CDS/IX/10A/1rxs_cor',
#  'CDS/IX/10A/cor_hst',
#  'CDS/IX/10A/cor_iras',
#  'CDS/IX/10A/cor_ned',
#  'CDS/IX/10A/cor_nvs',
#  'CDS/IX/10A/cor_pri',
#  'CDS/IX/10A/cor_ros',
#  'CDS/IX/10A/cor_ver',
#  'CDS/IX/10A/cor_wfc',
#  'CDS/IX/11/rosatsrc',
#  'CDS/IX/12/wgacat',
#  'CDS/IX/13/2e',
#  'CDS/IX/15/catalog',
#  'CDS/IX/16/3A',
#  'CDS/IX/18/catalog',
#  'CDS/IX/2/2a',
#  'CDS/IX/20A/batse',
#  'CDS/IX/20A/ulysses',
#  'CDS/IX/22/hfield',
#  'CDS/IX/22/hsrc',
#  'CDS/IX/22/ifield',
#  'CDS/IX/22/ipchri',
#  'CDS/IX/22/isrc',
#  'CDS/IX/22/sample',
#  'CDS/IX/22/targets',
#  'CDS/IX/24/hrifield',
#  'CDS/IX/24/hrisrc',
#  'CDS/IX/25/ipcfield',
#  'CDS/IX/25/ipcihut',
#  'CDS/IX/28A/hricat',
#  'CDS/IX/28A/seq',
#  'CDS/IX/29/rass_fsc',
#  'CDS/IX/30/2rxp',
#  'CDS/IX/30/seqp',
#  'CDS/IX/31/wgacat',
#  'CDS/IX/32/rosat',
#  'CDS/IX/32/table1',
#  'CDS/IX/32/table3',
#  'CDS/IX/35/deepsurv',
#  'CDS/IX/35/detect',
#  'CDS/IX/35/faint',
#  'CDS/IX/35/rap',
#  'CDS/IX/35/survey',
#  'CDS/IX/37/xmm1src',
#  'CDS/IX/39/xmm2slim',
#  'CDS/IX/4/4u',
#  'CDS/IX/40/xmm2is',
#  'CDS/IX/41/xmm2ir3s',
#  'CDS/IX/43/sources',
#  'CDS/IX/43/xcor',
#  'CDS/IX/44/summary',
#  'CDS/IX/44/xmm3r4s',
#  'CDS/IX/45/csc11',
#  'CDS/IX/46/summary',
#  'CDS/IX/46/xmm3r5s',
#  'CDS/IX/47/3xmmeu',
#  'CDS/IX/48/xgustwra',
#  'CDS/IX/49/list',
#  'CDS/IX/49/xxl1000a',
#  'CDS/IX/49/xxl100gc',
#  'CDS/IX/49/xxl_vla',
#  'CDS/IX/49/xxlpoint',
#  'CDS/IX/50/summary',
#  'CDS/IX/50/xmm3r6s',
#  'CDS/IX/51/table2',
#  'CDS/IX/53/xmmsl2c',
#  'CDS/IX/6/data',
#  'CDS/IX/8/catalog',
#  'CDS/J/A+A/113/61/table2',
#  'CDS/J/A+A/171/261/table1',
#  'CDS/J/A+A/177/131/table2',
#  'CDS/J/A+A/216/44/table3',
#  'CDS/J/A+A/227/82/table1a',
#  'CDS/J/A+A/229/362/table1',
#  'CDS/J/A+A/241/551/table2',
#  'CDS/J/A+A/241/551/table3',
#  'CDS/J/A+A/241/551/table4',
#  'CDS/J/A+A/243/386/table1',
#  'CDS/J/A+A/250/370/appena',
#  'CDS/J/A+A/250/370/appenf',
#  'CDS/J/A+A/267/515/table2',
#  'CDS/J/A+A/267/515/table3',
#  'CDS/J/A+A/275/101/stars',
#  'CDS/J/A+A/275/163/table1',
#  'CDS/J/A+A/275/201/table1',
#  'CDS/J/A+A/277/453/table1',
#  'CDS/J/A+A/278/36/table1',
#  'CDS/J/A+A/278/379/table1',
#  'CDS/J/A+A/281/161/radiostars',
#  'CDS/J/A+A/281/161/table9',
#  'CDS/J/A+A/281/375/table1',
#  'CDS/J/A+A/282/436/table1',
#  'CDS/J/A+A/283/759/qso',
#  'CDS/J/A+A/284/233/table1',
#  'CDS/J/A+A/285/247/objects',
#  'CDS/J/A+A/285/785/appena',
#  'CDS/J/A+A/286/17/table1',
#  'CDS/J/A+A/286/17/table2',
#  'CDS/J/A+A/291/261/table1',
#  'CDS/J/A+A/291/261/table2',
#  'CDS/J/A+A/295/206/table1a',
#  'CDS/J/A+A/296/727/table1',
#  'CDS/J/A+A/296/727/table2',
#  'CDS/J/A+A/297/391/table1',
#  'CDS/J/A+A/297/391/table2',
#  'CDS/J/A+A/298/115/table2',
#  'CDS/J/A+A/298/115/table5',
#  'CDS/J/A+A/299/238/table1',
#  'CDS/J/A+A/299/238/table3',
#  'CDS/J/A+A/299/347/table2',
#  'CDS/J/A+A/299/39/table1',
#  'CDS/J/A+A/300/323/table1',
#  'CDS/J/A+A/303/661/table1',
#  'CDS/J/A+A/303/661/table2',
#  'CDS/J/A+A/305/960/table1',
#  'CDS/J/A+A/308/573/table1',
#  'CDS/J/A+A/309/116/table2',
#  'CDS/J/A+A/309/749/tablea1',
#  'CDS/J/A+A/310/353/table2',
#  'CDS/J/A+A/310/353/table8',
#  'CDS/J/A+A/312/1031/table2',
#  'CDS/J/A+A/312/1031/table3',
#  'CDS/J/A+A/312/111/table1',
#  'CDS/J/A+A/312/439/table4',
#  'CDS/J/A+A/312/439/table5',
#  'CDS/J/A+A/312/439/table7',
#  'CDS/J/A+A/312/74/table3',
#  'CDS/J/A+A/314/191/tables',
#  'CDS/J/A+A/314/541/table1-2',
#  'CDS/J/A+A/314/615/table1',
#  'CDS/J/A+A/314/615/table2',
#  'CDS/J/A+A/316/147/table1',
#  'CDS/J/A+A/317/328/table5',
#  'CDS/J/A+A/317/423/snfield',
#  'CDS/J/A+A/317/689/sd',
#  'CDS/J/A+A/317/689/wd',
#  'CDS/J/A+A/319/18/appena',
#  'CDS/J/A+A/319/235/table1',
#  'CDS/J/A+A/319/33/table3',
#  'CDS/J/A+A/319/401/table1',
#  'CDS/J/A+A/319/413/table1',
#  'CDS/J/A+A/319/67/table1',
#  'CDS/J/A+A/321/123/table1',
#  'CDS/J/A+A/321/236/table3',
#  'CDS/J/A+A/323/139/table3',
#  'CDS/J/A+A/323/739/table1',
#  'CDS/J/A+A/323/739/table2',
#  'CDS/J/A+A/323/739/table3',
#  'CDS/J/A+A/323/739/table4',
#  'CDS/J/A+A/324/877/table1',
#  'CDS/J/A+A/325/159/table1',
#  'CDS/J/A+A/325/255/table1',
#  'CDS/J/A+A/325/255/table3',
#  'CDS/J/A+A/325/473/table1',
#  'CDS/J/A+A/325/473/table2',
#  'CDS/J/A+A/326/1044/table5',
#  'CDS/J/A+A/326/211/table1',
#  'CDS/J/A+A/326/751/stars',
#  'CDS/J/A+A/327/325/table2',
#  'CDS/J/A+A/327/522/gal',
#  'CDS/J/A+A/327/755/table1',
#  'CDS/J/A+A/327/755/table2',
#  'CDS/J/A+A/329/482/table4',
#  'CDS/J/A+A/330/108/table1',
#  'CDS/J/A+A/330/515/table1',
#  'CDS/J/A+A/330/990/table2',
#  'CDS/J/A+A/331/581/table2',
#  'CDS/J/A+A/331/633/table1',
#  'CDS/J/A+A/331/633/table2',
#  'CDS/J/A+A/331/633/table3',
#  'CDS/J/A+A/331/949/table1',
#  'CDS/J/A+A/333/471/table5',
#  'CDS/J/A+A/333/619/tablea1',
#  'CDS/J/A+A/333/619/tablea2',
#  'CDS/J/A+A/333/897/table2',
#  'CDS/J/A+A/335/467/table3',
#  'CDS/J/A+A/335/912/tables',
#  'CDS/J/A+A/336/339/table1a',
#  'CDS/J/A+A/336/339/table1b',
#  'CDS/J/A+A/336/35/table1',
#  'CDS/J/A+A/337/125/table1',
#  'CDS/J/A+A/337/125/table2',
#  'CDS/J/A+A/338/1066/stars',
#  'CDS/J/A+A/340/371/table2',
#  'CDS/J/A+A/341/121/table1',
#  'CDS/J/A+A/341/121/table3-4',
#  'CDS/J/A+A/341/121/table6',
#  'CDS/J/A+A/341/163/table3',
#  'CDS/J/A+A/341/818/table1',
#  'CDS/J/A+A/342/313/15um',
#  'CDS/J/A+A/342/313/7um',
#  'CDS/J/A+A/342/313/isocat',
#  'CDS/J/A+A/342/773/table3',
#  'CDS/J/A+A/342/773/table4',
#  'CDS/J/A+A/343/86/table1',
#  'CDS/J/A+A/343/93/table1',
#  'CDS/J/A+A/344/263/table5',
#  'CDS/J/A+A/345/471/table1',
#  'CDS/J/A+A/345/521/table3',
#  'CDS/J/A+A/345/521/table5',
#  'CDS/J/A+A/346/785/table1',
#  'CDS/J/A+A/346/785/table2',
#  'CDS/J/A+A/346/955/120-150p',
#  'CDS/J/A+A/346/955/120-150u',
#  'CDS/J/A+A/346/955/150u',
#  'CDS/J/A+A/346/955/60-90p',
#  'CDS/J/A+A/346/955/60-90u',
#  'CDS/J/A+A/346/955/90-120p',
#  'CDS/J/A+A/346/955/90-120u',
#  'CDS/J/A+A/347/47/table3',
#  'CDS/J/A+A/348/897/tablea6',
#  'CDS/J/A+A/349/448/table7',
#  'CDS/J/A+A/35/393/table4',
#  'CDS/J/A+A/350/805/object',
#  'CDS/J/A+A/352/228/table1',
#  'CDS/J/A+A/352/555/table1',
#  'CDS/J/A+A/352/600/stars',
#  'CDS/J/A+A/352/605/stars',
#  'CDS/J/A+A/353/1044/table4',
#  'CDS/J/A+A/353/287/stars',
#  'CDS/J/A+A/353/77/tablec1',
#  'CDS/J/A+A/354/169/table1',
#  'CDS/J/A+A/354/823/catalog',
#  'CDS/J/A+A/354/881/stars',
#  'CDS/J/A+A/355/138/table1',
#  'CDS/J/A+A/355/651/table3',
#  'CDS/J/A+A/356/141/catalog',
#  'CDS/J/A+A/356/238/table2',
#  'CDS/J/A+A/356/445/table1',
#  'CDS/J/A+A/356/445/table2',
#  'CDS/J/A+A/356/541/table1',
#  'CDS/J/A+A/357/1001/table2',
#  'CDS/J/A+A/358/257/table2',
#  'CDS/J/A+A/358/547/table1',
#  'CDS/J/A+A/358/77/tablea1',
#  'CDS/J/A+A/358/77/tableb1',
#  'CDS/J/A+A/359/227/table1',
#  'CDS/J/A+A/359/227/table2',
#  'CDS/J/A+A/359/227/table3',
#  'CDS/J/A+A/359/227/table4',
#  'CDS/J/A+A/359/347/table2',
#  'CDS/J/A+A/359/347/table3',
#  'CDS/J/A+A/359/597/table1a',
#  'CDS/J/A+A/359/865/table4',
#  'CDS/J/A+A/361/1011/position',
#  'CDS/J/A+A/361/1079/table1',
#  'CDS/J/A+A/361/1079/table2',
#  'CDS/J/A+A/361/1143/table4',
#  'CDS/J/A+A/362/799/table1',
#  'CDS/J/A+A/363/1040/table2',
#  'CDS/J/A+A/363/141/table1',
#  'CDS/J/A+A/363/141/table2',
#  'CDS/J/A+A/363/239/table2',
#  'CDS/J/A+A/363/29/table8',
#  'CDS/J/A+A/363/29/table9',
#  'CDS/J/A+A/363/517/table1',
#  'CDS/J/A+A/363/887/table1',
#  'CDS/J/A+A/364/102/stars',
#  'CDS/J/A+A/364/205/stars',
#  'CDS/J/A+A/364/391/table1',
#  'CDS/J/A+A/364/517/table1',
#  'CDS/J/A+A/364/665/stars',
#  'CDS/J/A+A/364/674/stars',
#  'CDS/J/A+A/364/712/table5',
#  'CDS/J/A+A/364/712/table6',
#  'CDS/J/A+A/365/110/stars',
#  'CDS/J/A+A/365/90/stars',
#  'CDS/J/A+A/366/428/table1',
#  'CDS/J/A+A/366/481/table2',
#  'CDS/J/A+A/366/498/table2',
#  'CDS/J/A+A/366/508/stars',
#  'CDS/J/A+A/366/68/table1',
#  'CDS/J/A+A/366/771/table3',
#  'CDS/J/A+A/366/771/table5',
#  'CDS/J/A+A/366/771/table6',
#  'CDS/J/A+A/366/771/table7',
#  'CDS/J/A+A/366/868/table2',
#  'CDS/J/A+A/367/297/table2',
#  'CDS/J/A+A/367/498/table1',
#  'CDS/J/A+A/367/498/table2',
#  'CDS/J/A+A/367/759/table3',
#  'CDS/J/A+A/367/759/table4',
#  'CDS/J/A+A/367/910/stars',
#  'CDS/J/A+A/368/1006/table1',
#  'CDS/J/A+A/368/797/seyfert1',
#  'CDS/J/A+A/368/797/seyfert2',
#  'CDS/J/A+A/368/845/table2',
#  'CDS/J/A+A/368/912/appen1',
#  'CDS/J/A+A/369/178/stars',
#  'CDS/J/A+A/369/249/stars',
#  'CDS/J/A+A/369/380/table3',
#  'CDS/J/A+A/369/380/table3b',
#  'CDS/J/A+A/369/862/table1',
#  'CDS/J/A+A/370/409/table2',
#  'CDS/J/A+A/370/468/table1',
#  'CDS/J/A+A/370/468/table5a',
#  'CDS/J/A+A/370/468/table5b',
#  'CDS/J/A+A/370/468/table6',
#  'CDS/J/A+A/370/468/table7',
#  'CDS/J/A+A/370/765/table1',
#  'CDS/J/A+A/370/78/table3',
#  'CDS/J/A+A/370/78/table4',
#  'CDS/J/A+A/370/900/table1',
#  'CDS/J/A+A/371/579/stars',
#  'CDS/J/A+A/371/579/table1',
#  'CDS/J/A+A/371/833/table3',
#  'CDS/J/A+A/371/833/table4',
#  'CDS/J/A+A/371/943/parcat',
#  'CDS/J/A+A/372/145/table2',
#  'CDS/J/A+A/372/145/table3',
#  'CDS/J/A+A/372/245/table1',
#  'CDS/J/A+A/372/276/table1',
#  'CDS/J/A+A/372/364/table11',
#  'CDS/J/A+A/372/364/table12',
#  'CDS/J/A+A/372/364/table8',
#  'CDS/J/A+A/372/364/table9',
#  'CDS/J/A+A/372/391/table4',
#  'CDS/J/A+A/372/L41/table1',
#  'CDS/J/A+A/373/1032/table1',
#  'CDS/J/A+A/373/24/table2',
#  'CDS/J/A+A/373/24/table3',
#  'CDS/J/A+A/373/24/tablea1',
#  'CDS/J/A+A/373/438/table2',
#  'CDS/J/A+A/373/576/table3',
#  'CDS/J/A+A/373/608/t2_8',
#  ...]

# %% [markdown]
# We have obtained from the mocserver the datasets which intersect the moc found at the url http://alasky.u-strasbg.fr/SDSS/DR9/color/Moc.fits, have the 'CDS' word in their IDs and finally, have a moc_sky_fraction with at least 1%.
